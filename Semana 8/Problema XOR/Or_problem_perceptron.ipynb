# %% [markdown]
# # Definición de perceptron

# %%
from IPython.display import Image

# Ruta de la imagen (reemplaza 'imagen.jpg' con la ruta de tu imagen)
ruta_imagen = 'C:\\Users\\USUARIO\\Downloads\\ModeloPerceptron-768x444.jpeg'

# Muestra la imagen
Image(filename=ruta_imagen)

# %%
class Perceptron:
    def __init__(self, num_inputs, learning_rate=0.1):
        self.weights = [random.uniform(-1, 1) for _ in range(num_inputs)]
        self.bias = random.uniform(-1, 1)
        self.learning_rate = learning_rate

    def step_function(self, x):
        return 1 if x >= 0 else 0

    def predict(self, inputs):
        y = sum(w * x for w, x in zip(self.weights, inputs)) + self.bias
        return self.step_function(y)

    def train(self, training_data, num_epochs):
        for _ in range(num_epochs):
            for inputs, target in training_data:
                prediction = self.predict(inputs)
                error = target - prediction
                for i in range(len(self.weights)):
                    self.weights[i] += self.learning_rate * error * inputs[i]
                self.bias += self.learning_rate * error
    
    def print_weights(self):
        print(self.weights)

# %%
X = [
    [0, 0],
    [0, 0.5],
    [0.5, 0.5],
    [0.7, 0.8],
    [0.9, 0.95],
    [0.4, 0.3]
]

y = [0, 0, 0, 1, 1, 0]

# %%
import random
# Preparar los datos de entrenamiento
training_data = list(zip(X, y))

# Crear un perceptrón y entrenarlo
perceptron = Perceptron(num_inputs=2)
perceptron.train(training_data, num_epochs=100)

# %%
for inputs, _ in training_data:
    prediction = perceptron.predict(inputs)
    print(f"Entrada: {inputs}, Predicción: {prediction}")

perceptron.print_weights()
# Out:
# Entrada: [0, 0], Predicción: 0
# Entrada: [0, 0.5], Predicción: 0
# Entrada: [0.5, 0.5], Predicción: 0
# Entrada: [0.7, 0.8], Predicción: 1
# Entrada: [0.9, 0.95], Predicción: 1
# Entrada: [0.4, 0.3], Predicción: 0
# [0.2526986491872875, 0.07048021486826944]
